# %% [markdown]
# <a href="https://colab.research.google.com/github/bbc18/jupyter-bbox-widget-anki/blob/main/Prueba_BBOX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://www.kaggle.com/code/maevaralafi/diving-into-ipython-widgets
# https://colab.research.google.com/notebooks/widgets.ipynb
# https://colab.research.google.com/github/ahmadkhan242/jupyter_widgets/blob/main/jupyter_widgets.ipynb
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html
# https://ipython-books.github.io/33-mastering-widgets-in-the-jupyter-notebook/
# https://freedium.cfd/https://towardsdatascience.com/bring-your-jupyter-notebook-to-life-with-interactive-widgets-bc12e03f0916
# https://colab.research.google.com/github/jupyter-widgets/ipywidgets/blob/master/docs/source/examples/Index.ipynb


# %pip install jupyter_bbox_widget ipywidgets genanki --quiet

#In colab you need to autorize external widgets such as jupyter_bbox_widget
from google.colab import output
output.enable_custom_widget_manager()

##--- Code to disable auto-scrolling for large images --- https://stackoverflow.com/questions/55546869/google-colaboratory-is-there-any-way-to-expand-the-height-of-the-result-cell-of
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'''))

from ipywidgets import widgets
from IPython.display import display
from jupyter_bbox_widget import BBoxWidget # Bounding Box Widget
from google.colab import widgets as google_widgets

import os
import json
import base64

def encode_image(filepath):
    """This is a helper function needed to show images in some versions of Jupyter Notebooks / Jupyter Labs"""
    with open(filepath, 'rb') as f:
        image_bytes = f.read()
    encoded = str(base64.b64encode(image_bytes), 'utf-8')
    return "data:image/jpg;base64,"+encoded

#Directory for input images
# !mkdir -p /content/images
# %cd /content/images

#Directory for output croppings used for flashcards
# !mkdir -p /content/croppings

#Example image file
# !wget https://nauticpedia.com/wp-content/uploads/2016/08/codigo-de-se%C3%B1ales-maritimas-internacional.jpg

from google.colab import files
#uploaded = files.upload() # to upload a Full Directory, please Zip it first (use WinZip)

# !ls

bbox_widget = BBoxWidget(
    image=encode_image('/content/images/codigo-de-señales-maritimas-internacional.jpg'),
    classes=['_', 'Front', 'Back'])

counter = 100

@bbox_widget.on_submit
def on_submit():
    global counter
    counter += 1
    # get front and back bboxes2
    front = next(bbox for bbox in bbox_widget.bboxes if bbox['label']=='Front')
    back = next(bbox for bbox in bbox_widget.bboxes if bbox['label']=='Back')
    # do the cropping/saving here

    # rename labels adding counter
    new_bboxes = []
    for bbox in bbox_widget.bboxes:
        new_bbox = {**bbox}
        if new_bbox['label'] in ('Front', 'Back'):
            new_bbox['label'] += f'_{counter}'
        new_bboxes.append(new_bbox)
    bbox_widget.bboxes = new_bboxes
    # or maybe just clear them instead?

# display the widget
#bbox_widget
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.0 MB/s eta 0:00:00
# /content/images
# --2024-01-03 20:52:04--  https://nauticpedia.com/wp-content/uploads/2016/08/codigo-de-se%C3%B1ales-maritimas-internacional.jpg
# Resolving nauticpedia.com (nauticpedia.com)... 188.165.128.186
# Connecting to nauticpedia.com (nauticpedia.com)|188.165.128.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 410719 (401K) [image/jpeg]
# Saving to: ‘codigo-de-señales-maritimas-internacional.jpg’
#
# codigo-de-señales-m 100%[===================>] 401.09K   649KB/s    in 0.6s
#
# 2024-01-03 20:52:05 (649 KB/s) - ‘codigo-de-señales-maritimas-internacional.jpg’ saved [410719/410719]
#
# codigo-de-señales-maritimas-internacional.jpg

# %%
counter_widget = widgets.BoundedIntText(
                  value=0,
                  min=0,
                  max=99999,
                  step=1,
                  description='Image pair #:',
                  disabled=False
              )

deck_name_widget = widgets.Text(
                        value='QnA',
                        placeholder='Enter_deck_name',
                        description='Anki deck name:',
                        disabled=False
                    )


load_local_img_button = widgets.Button(
                          description='Load image',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to upload an image from local PC'
                      )

def load_local_img_eventhandler(button):
  probar tabs_widget.clear_tab(0)
  with tab_0_output:
    tab_0_output.clear_output()
    print('Please select image file to load or press cancel to continue')
    uploaded = files.upload()
    for fn in uploaded.keys():
      print('User uploaded file "{name}" with length {length} bytes'.format(
          name=fn, length=len(uploaded[fn])))
    #Refresh tab contents
    tab_0_output.clear_output()
    display(tab0)
    print(uploaded.keys())


load_local_img_button.on_click(load_local_img_eventhandler)


load_local_bbox_button = widgets.Button(
                          description='Load bounding boxes',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to upload previously generated bounding boxes from local PC'
                      )


load_url_img_button = widgets.Button(
                          description='Image from url',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to load an image from an URL'
                      )


preview_deck_button = widgets.Button(
                          description='Preview Anki deck',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to preview Anki deck '
                      )

generate_deck_button = widgets.Button(
                          description='Download Anki deck',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to generate and download Anki deck '
                      )


save_bbox_button = widgets.Button(
                          description='Save bounding boxes',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to save bounding boxes to local PC for future use'
                      )
"""
counter_widget
deck_name_widget
load_local_img_button
load_url_img_button
load_local_bbox_button
preview_deck_button
generate_deck_button
save_bbox_button
"""

"""
from IPython.display import display

display(counter_widget,
deck_name_widget,
load_local_img_button,
load_url_img_button,
load_local_bbox_button,
preview_deck_button,
generate_deck_button,
save_bbox_button)
"""

line_boxes = []

line_boxes.append( widgets.HBox([deck_name_widget, counter_widget]) )
line_boxes.append( widgets.HBox([load_local_img_button, load_url_img_button]) )
line_boxes.append( widgets.HBox([preview_deck_button, generate_deck_button]) )
line_boxes.append( widgets.HBox([load_local_bbox_button, save_bbox_button]) )


tab0 = widgets.VBox(line_boxes)

"""
tab = widgets.Tab()
tab.children = [tab1,bbox_widget]
tab.titles = ['Configuración','Crops']
#display(tab)
tab
"""

##--- Code to disable auto-scrolling for large images --- https://stackoverflow.com/questions/55546869/google-colaboratory-is-there-any-way-to-expand-the-height-of-the-result-cell-of
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'''))


#Using Output objects in order to be able to clear the contents of each tab
tab_0_output =  widgets.Output()
tab_1_output =  widgets.Output()

with tab_0_output:
  display(tab0)

with tab_1_output:
  display(bbox_widget)


tabs_widget = google_widgets.TabBar(['Configuration','Image'], location='top')
with tabs_widget.output_to(0):
  display(tab_0_output)
with tabs_widget.output_to(1,select=False)):
  display(tab_1_output)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id11"></div>
# Output()
# Output()

# %%
# !ls
# !pwd
# Out:
# 'codigo-de-señales-maritimas-internacional (1) (1).yaml'
# 'codigo-de-señales-maritimas-internacional (1).yaml'
#  codigo-de-señales-maritimas-internacional.jpg
#  codigo-de-señales-maritimas-internacional.yaml
# /content/images

# %% [markdown]
# # Nueva sección

# %%
counter_widget = widgets.BoundedIntText(
                  value=0,
                  min=0,
                  step=1,
                  description='Image pair #:',
                  disabled=False
              )

deck_name_widget = widgets.Text(
                        value='QnA',
                        placeholder='Enter_deck_name',
                        description='Anki deck name:',
                        disabled=False
                    )


load_local_img_button = widgets.Button(
                          description='Load image',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to upload an image from local PC'
                      )




load_local_bbox_button = widgets.Button(
                          description='Load bounding boxes',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to upload previously generated bounding boxes from local PC'
                      )


load_url_img_button = widgets.Button(
                          description='Image from url',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to load an image from an URL'
                      )


preview_deck_button = widgets.Button(
                          description='Preview Anki deck',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to preview Anki deck '
                      )

generate_deck_button = widgets.Button(
                          description='Download Anki deck',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to generate and download Anki deck '
                      )


save_bbox_button = widgets.Button(
                          description='Save bounding boxes',
                          disabled=False,
                          button_style='', # 'success', 'info', 'warning', 'danger' or ''
                          tooltip='Click to save bounding boxes to local PC for future use'
                      )

button



widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400,
)

tab_contents = ['P0', 'P1', 'P2', 'P3', 'P4']
children = [widgets.Text(description=name) for name in tab_contents]
tab = widgets.Tab()
tab.children = children
tab.titles = [str(i) for i in range(len(children))]
tab
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e798b6411c84> in <cell line: 63>()
#      61                       )
#      62
# ---> 63 button
#      64
#      65
#
# NameError: name 'button' is not defined
